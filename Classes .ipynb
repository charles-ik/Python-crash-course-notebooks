# %% [markdown]
# # EXERCISE
#
# 9-1. Restaurant: Make a class called Restaurant.
# > - The `__init__()` method for Restaurant should store two attributes: a restaurant_name and a cuisine_type.
# > - Make a method called `describe_restaurant()` that prints these two pieces of information, and a method called `open_restaurant()` that prints a message indi- cating that the restaurant is open.
# > - Make an instance called restaurant from your class. Print the two attributes individually, and then call both methods.
#
# 9-2. Three Restaurants:
# > - Start with your class from Exercise 9-1.
# > - Create three different instances from the class, and call `describe_restaurant()` for each instance.
#
# 9-3. Users:
# > - Make a class called User. Create two attributes called first_name and last_name, and then create several other attributes that are typically stored in a user profile.
# >- Make a method called `describe_user()` that prints a summary of the user’s information.
# >- Make another method called `greet_user()` that prints a personalized greeting to the user.
# >- Create several instances representing different users, and call both methods for each user.

# %%
#9.1
class Restaurant: 
        """Class to store information about a basic resturant"""
        def __init__(self,restaurant_name, cuisine_type):
            self.restaurant_name = restaurant_name.title()
            self.cuisine_type = cuisine_type
            
        def describe_restaurant(self): #all methods in a class need to atleast take the self parameter
            print(f"This restaurant's name is {self.restaurant_name} and they serve {self.cuisine_type} food")
        
        def open_restaurant(self):
            print(f"The {self.cuisine_type} spot {self.restaurant_name} is now open")
            
thai_place = Restaurant("Rosa's Thai", "Thai")  #this creates an instance of this class and assigns it the the variable

print(thai_place.restaurant_name) #this accesses the attribute value of the instance that has been created
print(thai_place.cuisine_type)

print("\n")

thai_place.describe_restaurant() #this calls the method for the created instance
thai_place.open_restaurant()

#9.2

maccies = Restaurant("Mcdonalds","bugers") # instantiating the maccies object from the class Restaurant
kfc = Restaurant("Kentucky Fried Chicken", "chicken")

print(maccies.restaurant_name)
print(kfc.restaurant_name)

maccies.describe_restaurant()
kfc.open_restaurant()

# %%
# 9.3
class User:
    '''Initalize the user'''
    def __init__(
        self, 
        first_name, 
        last_name, 
        height, 
        weight ,
        country_of_origin
    ):
        
        self.first_name = first_name 
        self.last_name = last_name 
        self.height = height 
        self.weight = weight
        self.country = country_of_origin
    
    def describe_user(self):
        
        #detailslist = list(self.__dict__.values()) 
        # store a dictionary of all the user's info (
        #so only takes the values of the dictionary that was created) to the variable 
        user_info_dict =(self.__dict__) # this creates a user of all the keys and values for the user's attributes 
        #print(user_info_dict)
        
        for key , value in user_info_dict.items():
            print(f"{key}: {value}")

user1 = User('John', 'Doe', 180, 75, 'USA')
user2 = User("henry","Cummings", 171, 88, "UK")

user1.first_name = "mark" #changes the value directly 

user1.describe_user()
user2.describe_user()

# %% [markdown]
# # EXERCISE
#
#
# 9-4. Number Served:
# > - Start with your program from Exercise 9-1 (page 162).
# > - Add an attribute called number_served with a default value of 0.
# > - Create an instance called restaurant from this class.
# > - Print the number of customers the restaurant has served, and then change this value and print it again.
# > - Add a method called set_number_served() that lets you set the number of customers that have been served.
# >> - Call this method with a new number and print the value again.
# >> - Add a method called increment_number_served() that lets you increment the number of customers who’ve been served.
# >>> - Call this method with any number you like that could represent how many customers were served in, say, a day of business.
#
# 9-5. Login Attempts:
# > - Add an attribute called login_attempts to your User class from Exercise 9-3 (page 162).
# > - Write a method called increment_login _attempts() that increments the value of login_attempts by 1.
# >- Write another method called reset_login_attempts() that resets the value of login_attempts to 0.
# >- Make an instance of the User class and call increment_login_attempts() several times.
# >>- Print the value of login_attempts to make sure it was incremented properly, and then call reset_login_attempts().
# >>>- Print login_attempts again to make sure it was reset to 0.

# %%
#9.4 

class Restaurant():
    """A class representing a restaurant."""

    def __init__(self, name, cuisine_type):
        """Initialize the restaurant."""
        self.name = name.title()
        self.cuisine_type = cuisine_type
        self.number_served = 0

    def describe_restaurant(self):
        """Display a summary of the restaurant."""
        msg = f"{self.name} serves wonderful {self.cuisine_type}."
        print(f"\n{msg}")

    def open_restaurant(self):
        """Display a message that the restaurant is open."""
        msg = f"{self.name} is open. Come on in!"
        print(f"\n{msg}")
        
    def set_number_served(self,number):#number is now a parameter of the method , user can pass through an argument when calling the function to change it's value
        '''Allows you to set the number of people that have been served'''
        self.number_served = number 
        print(f"The number of people you say you have served is {self.number_served}")
    
    def increment_number_served(self,customers_today):
        '''Increment the value of the number of people served'''
        self.number_served += customers_today
        print(self.number_served)
    
    
        
        

        

restaurant = Restaurant('the mean queen', 'pizza',)# first obviously instantiate the object restaurant

restaurant.describe_restaurant()# method contains print statement so i can see that the value has indeed changed
print("\n")

print(f'The default value of number served is :{restaurant.number_served}')#just prints the default value as value has not been changed yet
restaurant.number_served = 200 #an example of direct modification of the value. 
print(f"the number of people served is {restaurant.number_served}")
restaurant.set_number_served(300)#passes an argument through method set_number_served
restaurant.increment_number_served(40) #increments this value on the number of people served as per the method

# %%
#9.5

class User:
    '''Initalize the user'''
    def __init__(
        self, 
        first_name, 
        last_name, 
        height, 
        weight ,
        country_of_origin
    ):
        
        self.first_name = first_name 
        self.last_name = last_name 
        self.height = height 
        self.weight = weight
        self.country = country_of_origin
        self.login_attempts = 0
    
    def describe_user(self):
        '''Creates a dictionary of user info the prints 
        it in pairs '''
        
        #detailslist = list(self.__dict__.values()) 
        # store a dictionary of all the user's info (
        #so only takes the values of the dictionary that was created) to the variable 
        user_info_dict =(self.__dict__) # this creates a user of all the keys and values for the user's attributes 
        #print(user_info_dict)
        
        for key , value in user_info_dict.items():
            print(f"{key}: {value}")
            
    def increment_login_attempt(self):
        '''Increments the login attempts by 1 each time '''
        self.login_attempts += 1 
        """
        the "+=" operator does not reset the value to 1 (int this case), 
        however it simply increments what ever the value if by 1 each time 
        """
        
    def reset_login_attempts(self):
        self.login_attempts = 0 
        
        
        
user1 = User("John", "Doe", 180, 80, "United States")
user1.describe_user()


"""Calling the increment login_attempt several time and seeing the changes"""
print(f"Your current login attempts are : {user1.login_attempts}")
user1.increment_login_attempt()
print(f"Your current login attempts are : {user1.login_attempts}")
user1.increment_login_attempt()
print(f"Your current login attempts are : {user1.login_attempts}")
user1.increment_login_attempt()
print(f"Your current login attempts are : {user1.login_attempts}")

user1.reset_login_attempts()
print(f"Your current login attempts are now reset to : {user1.login_attempts}")

# %% [markdown]
# # EXERCISE
#
# ### 9-6. Ice Cream Stand:
#
# - Write a class named IceCreamStand that inherits from the Restaurant class.
# >- If the Restaurant class doesn't exist, you will need to create it first. This class would typically include attributes like restaurant_name and cuisine_type, and methods like describe_restaurant() and open_restaurant().
# - Add an attribute to the IceCreamStand class called flavors, which stores a list of ice cream flavors.
# - Write a method that displays these flavors.
# - Create an instance of IceCreamStand and call the method you created to display the flavors.
#
# ### 9-7. Admin:
#
# - Write a class named Admin that inherits from the User class.
# >- If the User class doesn't exist, you will need to create it first. This class would typically include attributes like first_name, last_name, username, email, and location, and methods like describe_user() and greet_user().
# - Add an attribute to the Admin class called privileges, which stores a list of strings representing administrator privileges.
# - Write a method named show_privileges() that lists the administrator's set of privileges.
# - Create an instance of Admin and call your show_privileges() method.
#
# ### 9-8. Privileges:
#
# - Write a new class named Privileges.
# - This class should have one attribute, privileges, which stores a list of strings.
# - Move the show_privileges() method from the Admin class to this Privileges class.
# - Include an instance of the Privileges class as an attribute in the Admin class.
# - Create a new instance of Admin and use your method to show its privileges.
#
# ### 9-9. Battery Upgrade:
#
# - If not already present, create the ElectricCar and Battery classes, with the latter being an attribute of the former.
# - Add a method to the Battery class called upgrade_battery().
# >- This method should check the battery size and set the capacity to 100 if it isn't already.
# - Create an instance of ElectricCar with a default battery size.
# - Call get_range() method (which should be part of the Battery class) once, and then call get_range() again after calling upgrade_battery().
# >- You should see an increase in the car's range.

# %%
# 9.7 

class User:
    '''Initalize the user'''
    def __init__(
        self, 
        first_name, 
        last_name, 
        height, 
        weight ,
        country_of_origin
    ):
        
        self.first_name = first_name 
        self.last_name = last_name 
        self.height = height 
        self.weight = weight
        self.country = country_of_origin
        self.login_attempts = 0
    
    def describe_user(self):
        '''Creates a dictionary of user info the prints 
        it in pairs '''
        
        #detailslist = list(self.__dict__.values()) 
        # store a dictionary of all the user's info (
        #so only takes the values of the dictionary that was created) to the variable 
        user_info_dict =(self.__dict__) # this creates a user of all the keys and values for the user's attributes 
        #print(user_info_dict)
        
        for key , value in user_info_dict.items():
            print(f"{key}: {value}")
            
    def increment_login_attempt(self):
        '''Increments the login attempts by 1 each time '''
        self.login_attempts += 1 
        """
        the "+=" operator does not reset the value to 1 (int this case), 
        however it simply increments what ever the value if by 1 each time 
        """
        
    def reset_login_attempts(self):
        self.login_attempts = 0 
        
        
class Admin(User):
    def __init__(
        self,
        first_name, 
        last_name, 
        height, 
        weight ,
        country_of_origin
    ):
        super().__init__(
        
        first_name, 
        last_name, 
        height, 
        weight ,
        country_of_origin
        
        )
        
        self.privileges = [
            "can add users",
            "can delete users",
            "can ban users",
            "can modify user profiles",
            "can reset user passwords",
            "can view user activity logs",
            "can modify system settings",
            "can add or delete content",
            "can approve or reject user-generated content",
            "can send messages to all users",
            
        ]
        
    def show_privileges(self): 
        for privilege in self.privileges:
            print(f"- {privilege}")
            

admin1 = Admin("John", "Doe", 180, 80, "United States")

admin1.describe_user()

print("\n")

admin1.show_privileges()

# %%
# 9.6 Ice cream stand 

class Restaurant():
    """A class representing a restaurant."""

    def __init__(self, name, cuisine_type):
        """Initialize the restaurant."""
        self.name = name.title()
        self.cuisine_type = cuisine_type

    def describe_restaurant(self):
        """Display a summary of the restaurant."""
        msg = f"{self.name} serves wonderful {self.cuisine_type}."
        print(f"\n{msg}")

    def open_restaurant(self):
        """Display a message that the restaurant is open."""
        msg = f"{self.name} is open. Come on in!"
        print(f"\n{msg}")
        
class IceCreamStand(Restaurant):
    def __init__(self,name, cuisine_type = "Ice cream",):
        '''Initalise the subclass's __innit__ method 
        Should include:
        (self, parent_arg1, parent_arg2, subclass_arg)
        
        '''
        super().__init__(name,cuisine_type)
        '''super() function is used to call the attributes of the 
        parent (super) class that way the sub class inherits them'''

        self.flavors = []

    def describe_flavors(self):
        """Display the flavors available."""
        print("\nWe have the following flavors available:")
        for flavor in self.flavors:
            print(f"- {flavor.title()}")
        
res1 = IceCreamStand("benihana",) #default cusine type of ice cream is passed through the method in the class
res1.describe_restaurant()
res1.flavors = [ "mint", "chocolate", "Vanilia", "coffee flavored"]
res1.describe_flavors()
