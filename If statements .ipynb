# %% [markdown]
# # EXERCISE
#
# 5-1.
#
#
# Conditional Tests: Write a series of conditional tests.
#
# Print a statement describing each test and your prediction for the results of each test.
#
# Your code should look something like this:
# ```python
#                   car = 'subaru'
#                   print("Is car == 'subaru'? I predict True.")
#                   print(car == 'subaru')
#                   print("\nIs car == 'audi'? I predict False.")
#                   print(car == 'audi')
#
# ```
# • Look closely at your results, and make sure you understand why each line evaluates to True or False.
#
# • Create at least ten tests. Have at least five tests evaluate to True and another five tests evaluate to False.
#
# 5-2.
# More Conditional Tests: You don’t have to limit the number of tests you create to ten.
# If you want to try more comparisons, write more tests and add them to conditional_tests.py.
#
# Have at least one True and one False result for each of the following:
#
# • Tests for equality and inequality with strings
#
# • Tests using the lower() method
#
# • Numerical tests involving equality and inequality, greater than and less than, greater
# than or equal to, and less than or equal to
#
# • Tests using the and keyword and the or keyword
#
# • Test whether an item is in a list
#
# • Test whether an item is not in a list

# %%
car = "audi"
print (car == "subaru")


food = " Mango "
print (f"The answer is {food.lower().strip() == 'mango' }") #white space is removed fdrom left and right side by the strip method

num_test = (2+2)

print(num_test >= 4 and num_test < 5 )

if num_test >3 or num_test <100:
    print("thats the right number")

# %%
boy_names = ["Liam", "Noah", "Oliver", "Henry", "Alexander", "Mason", "Michael", "Ethan", "Daniel", "Jacob", "Logan", "Jackson", "Levi"]
len(boy_names)
del boy_names[-4:-1]# slices the 4 from end element all the way to the last (end) element  
print(boy_names)
if "Noah" in boy_names and "Jerry" not in boy_names: 
    print("yep noah's in there")
else: 
    print("thats the wrong number!!!")

# %% [markdown]
# # EXERCISE
#
# 5-3. Alien Colors #1:
#
# - Create a variable called alien_color and assign it a value of 'green', 'yellow', or 'red'.
# - If alien_color is 'green', print a message that the player earned 5 points.
#
#
# 5-4. Alien Colors #2:
#
# - Choose a color for an alien and assign it to alien_color.
# - If alien_color is 'green', print a message that the player earned 5 points for shooting the alien.
# - If alien_color is not 'green', print a message that the player earned 10 points.
#
# 5-5. Alien Colors #3:
#
# - Choose a color for an alien and assign it to alien_color.
# - If alien_color is 'green', print a message that the player earned 5 points.
# - If alien_color is 'yellow', print a message that the player earned 10 points.
# - If alien_color is 'red', print a message that the player earned 15 points.
#
# 5-6. Stages of Life:
#
# Set a value for the variable age.
# - If age is less than 2, print a message that the person is a baby.
# - If age is at least 2 but less than 4, print a message that the person is a toddler.
# - If age is at least 4 but less than 13, print a message that the person is a kid.
# - If age is at least 13 but less than 20, print a message that the person is a teenager.
# - If age is at least 20 but less than 65, print a message that the person is an adult.
# - If age is 65 or older, print a message that the person is an elder.
#
# 5-7. Favorite Fruit:
#
# - Create a list called favorite_fruits containing your three favorite fruits.
# - Check if 'banana' is in favorite_fruits and print a statement if it is.
# - Check if 'apple' is in favorite_fruits and print a statement if it is.
# - Check if 'orange' is in favorite_fruits and print a statement if it is.
# - Check if 'strawberry' is in favorite_fruits and print a statement if it is.
# - Check if 'mango' is in favorite_fruits and print a statement if it is.

# %%
alien_color = "green  "

if alien_color.lower().strip() == "green":
    print("You passed you just earned 5 points")
else:
    print ("You failed sorry")

alien_color = ["green", "yellow", "red"]

color = alien_color[1]

print (f"\n {color}\n")

if color == "green":
    print("well done 5 points")
elif color == "yellow":
    print("Well done 10 points")
elif color == "red":
    print("well done 15 points")
    
# better version 
if color == "green":
    points = 5
elif color == "yellow":
    points = 10
elif color == "red":
    points = 15

print(f"Well done you got {points} points")

# %%
# 5.6 

stage_of_life = ["a baby", "a toddler", "a kid", "a teenager", "an adult", "an elder"]


age = int(input("Enter your age \t"))

if age < 2:
    stage = stage_of_life[0]
elif age >= 2 and age < 4: 
    stage = stage_of_life[1]
elif age >=4 and age < 13:
    stage = stage_of_life[2]
elif age >=13 and age < 20: 
    stage = stage_of_life[3]
elif age >= 20 and age < 65: 
    stage = stage_of_life[4]
elif age >= 65:
    stage = stage_of_life[5]
    

print(f"you my friend are {stage} , congrats")

# %%
# 5-7. Favorite Fruit:

# Create a list called favorite_fruits containing your three favorite fruits.
# Check if 'banana' is in favorite_fruits and print a statement if it is.
# Check if 'apple' is in favorite_fruits and print a statement if it is.
# Check if 'orange' is in favorite_fruits and print a statement if it is.
# Check if 'strawberry' is in favorite_fruits and print a statement if it is.
# Check if 'mango' is in favorite_fruits and print a statement if it is.

# obviously if this can be solved with a set of simple if statements one after the other. 


# this code doesn't not work exactly as intended 



# fruits = ["banana", "kiwi", "mango"]

# your_fruit =input("give me your fav fruit ")
# fav = " "
# for fruit in fruits: 
#     if fruit and your_fruit.lower().split() == "banana" :
#         fav = fruits[0]
#     elif fruit and your_fruit.lower().split() == "kiwi":
#         fav = fruits[1]
#     elif fruit and your_fruit.lower().split() == "mango":
#         fav = fruits[2]
        
# if your_fruit == fav: 
#     print(f"damn sounds like we both love {fav}")
# else:
#     print("thats cool not for me though")

# re-write to make it make more sense

fruits = ["banana", "kiwi", "mango"]

user_fruit = input("give me your fav fruit ")
favorite = " "

if user_fruit.lower() == "banana":
    favorite = fruits[0] #directly assigns an item from the list to the variable ' favortite'
elif user_fruit.lower() == "kiwi":
    favorite = fruits[1]
elif user_fruit.lower() == "mango":
    favorite = fruits[2]

if user_fruit.lower() == favorite.lower(): # this directly compares the user's fruit choice to the item from the list which was assigned in our if statements
    print(f"Damn, sounds like we both love {favorite}!")
else: 
    print("That's cool, not for me though.")
# Out:
# give me your fav fruit kiwi
# Damn, sounds like we both love kiwi!

# %%
fruits = ["banana", "kiwi", "mango"]


user_input = ()
for i in range(0,3):
    listed = fruits[i]
    if listed in fruits: 
        print(f"you really like {listed}")
    
# if "banana" in fruits:
#     print("You really like bananas")

# %%
# 5.9

# checking empty list 

toppings = [] 
if toppings: #this line checks whether a list is empty is the list is empty the if statment is skipped 
    for topping in toppings:
        print(f"Adding {topping}.")
print("\n Nothing to add , seems like you want a plain pizza buddy ")

# %% [markdown]
# # EXERCISE
#
# 5-8.
# Hello Admin:
# Make a list of five or more usernames, including the name 'admin'.
# Imagine you are writing code that will print a greeting to each user after they log in to a website.
# Loop through the list, and print a greeting to each user:
# • If the username is 'admin', print a special greeting, such as Hello admin, would you like to see a status report?
#
# • Otherwise, print a generic greeting, such as Hello Jaden, thank you for logging in again.
# 5-9.
# No Users: Add an if test to hello_admin.py to make sure the list of users is not empty.
#
# • If the list is empty, print the message We need to find some users!
#
# • Remove all of the usernames from your list, and make sure the correct message is printed.
#
# 5-10. Checking Usernames: Do the following to create a program that simulates
# how websites ensure that everyone has a unique username.
#
# • Make a list of five or more usernames called current_users.
#
# • Make another list of five usernames called new_users. Make sure one or
# two of the new usernames are also in the current_users list.
#
# • Loop through the new_users list to see if each new username has already been used. If it has, print a message that the person will need to enter a new username. If a username has not been used, print a message saying that the username is available.
#
# • Make sure your comparison is case insensitive. If 'John' has been used, 'JOHN' should not be accepted. (To do this, you’ll need to make a copy of current_users containing the lowercase versions of all existing users.)
#
# 5-11.
# Ordinal Numbers: Ordinal numbers indicate their position in a list, such as 1st or 2nd. Most ordinal numbers end in th, except 1, 2, and 3.
#
# • Store the numbers 1 through 9 in a list.
#
# • Loop through the list.
#
# • Use an if-elif-else chain inside the loop to print the proper ordinal end- ing for each number. Your output should read "1st 2nd 3rd 4th 5th 6th 7th 8th 9th", and each result should be on a separate line

# %%
# 5.9

usernames = ["john123", "admin", "alexander42", "sophia67", "daniel555"]


#del usernames[:]  # - this deletes all the elements from the list
if usernames: # this checks if the list is empty , if not the code runs
    for name in usernames:
        if name == "admin":
            print(f"Hello {name} would you like to see a status report? \n")
        else: 
            print (f"Hello {name}, thank you for logging in again \n")
else: # else statement , if the list is empty this is the code that run. 
    print("We need to find some users!")

# %%
# 5.10 



# current_user_copy = current_users[:]
# new_users


# other_names = [other for other in new_users] # creates a list for all the elements in the 
# print (other_names)

# user_index = [index for index in current_users if index == other_names]
# print(user_index)


# for user in current_users: 
#     for name in new_users:
#         if user == name:
#             print(f" Hi {name} gonna need you to pick a new username buddy")
#         else:
#             print(f"Go on ahead {name} that username is avaliable")



current_users = ["john123", "charles45", "alexander42", "sophia67", "daniel555"]

new_users = ["lily22", "maximus78", "sophia67", "michael23", "charles45"]

for user in current_users:
    match_found = False  # Flag variable to track if a match is found
    
    for name in new_users:
        if user == name:
            print(f"Hi {name}, gonna need you to pick a new username, buddy.")
            match_found = True
            break  # No need to continue checking once a match is found
    
    if not match_found:
        print(f"No match found for {user}.")
        
print('\n  The othter way of creating of solving the question that was presented. \n')        
    
current_users = ['eric', 'willie', 'admin', 'erin', 'Ever']
new_users = ['sarah', 'Willie', 'PHIL', 'ever', 'Iona']

current_users_lower = [user.lower() for user in current_users]

for new_user in new_users:
    if new_user.lower() in current_users_lower:
        print(f"Sorry {new_user}, that name is taken.")
    else:
        print(f"Great, {new_user} is still available.")
# Out:
# No match found for john123.
# Hi charles45, gonna need you to pick a new username, buddy.
# No match found for alexander42.
# Hi sophia67, gonna need you to pick a new username, buddy.
# No match found for daniel555.
#
#
#
# Great, sarah is still available.
# Sorry Willie, that name is taken.
# Great, PHIL is still available.
# Sorry ever, that name is taken.
# Great, Iona is still available.

# %%
# 5-11.
# Ordinal Numbers: Ordinal numbers indicate their position in a list, such as 1st or 2nd. Most ordinal numbers end in th, except 1, 2, and 3.

# • Store the numbers 1 through 9 in a list.

# • Loop through the list.

# • Use an if-elif-else chain inside the loop to print the proper ordinal end- ing for each number. Your output should read "1st 2nd 3rd 4th 5th 6th 7th 8th 9th", and each result should be on a separate line


numbers = list(range(1,10)) # creates a list of 1 to 9 
print(numbers)

for num in numbers: 
    if num == 1:
        num = str(num) + "st" #appends "st" at the end of number one
    elif num == 2:
        num = str(num) + "nd"
    elif num == 3: 
        num = str(num) + "rd"
    else: 
        num = str(num) + "th"
    print (num)
    
 # normally in an if-elif-else chain. python runs the chain until one of the conditions is true
# then the rest of the chain is ignored. 
# however beause this is a for loop. python loops through each time and checks that the condition 
# under each (if , elif or else) is true. stop running then runs the loops again
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 1st
# 2nd
# 3rd
# 4th
# 5th
# 6th
# 7th
# 8th
# 9th
